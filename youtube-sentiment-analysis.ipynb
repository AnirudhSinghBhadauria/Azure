# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# #### Using Robera model form hugging face

# %%
comment_df = pd.read_parquet("/kaggle/input/mrbeast-video-comments/100IdenticalTw_snX5YyflrGw_20240928160000.parquet")
